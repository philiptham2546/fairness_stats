# %%
import pandas as pd

# %%
coding = pd.read_csv("Coding proposals - Sheet1.csv")

# %%
coding
# Out:
#                                    Presentation title  \
# 0                                       Amazon resume
# 1          AI in Voice Infringement - China 2023 case
# 2                           2019 Apple Card Bias Case
# 3                     Spotify’s Recommendation System
# 4                              AI-generated Art/Music
# ..                                                ...
# 56  Auditing the audits': takeaways from analyzing...
# 57  Biases found in Synthetic or Pseudo Data and D...
# 58               Claude Interviewer Tool for Research
# 59  Age and Race Biases in Autonomous Driving Systems
# 60                              Turnitin AI Detection
#
#    Industry (where is AI used?) (multi-select possible)  \
# 0   "Internal business operations, workplace & lab...
# 1   ?/NA (presentation doesn't talk about specific...
# 2                      "Finance, banking & insurance"
# 3   Cultural representation, "Social media, sports...
# ...

# %%
coding.head()
# Out:
#                            Presentation title  \
# 0                               Amazon resume
# 1  AI in Voice Infringement - China 2023 case
# 2                   2019 Apple Card Bias Case
# 3             Spotify’s Recommendation System
# 4                      AI-generated Art/Music
#
#   Industry (where is AI used?) (multi-select possible)  \
# 0  "Internal business operations, workplace & lab...
# 1  ?/NA (presentation doesn't talk about specific...
# 2                     "Finance, banking & insurance"
# 3  Cultural representation, "Social media, sports...
# 4  Cultural representation, "Social media, sports...
#
#     AI use (how is AI used?) (multi-select possible)  \
# 0  Classification tasks (speech/voice/age recogni...
# 1                                      Generative AI
# 2  Classification tasks (speech/voice/age recogni...
# 3                             Recommendation systems
# 4                                      Generative AI
#
# ...

# %%
coding.columns
# Out:
# Index(['Presentation title',
#        'Industry (where is AI used?) (multi-select possible)',
#        'AI use (how is AI used?) (multi-select possible)',
#        'Fairness issue (multi-select possible)',
#        'Orientation (multi-select not possible)'],
#       dtype='str')

# %%
coding.rename(columns={"Presentation title": "title", "Industry (where is AI used?) (multi-select possible)": "ind", "AI use (how is AI used?) (multi-select possible)": "use", "Fairness issue (multi-select possible)": "issue", "Orientation (multi-select not possible)": "orientation"}, inplace=True)

# %%
coding.columns
# Out:
# Index(['title', 'ind', 'use', 'issue', 'orientation'], dtype='str')

# %%
coding['ind'].value_counts()
# Out:
# ind
# "Social media, sports, entertainment, & platforms"                                         9
# ?/NA (presentation doesn't talk about specific industry)                                   8
# "Government, infrastructure management, social welfare"                                    8
# "Internal business operations, workplace & labor dynamics"                                 7
# Education & academia                                                                       7
# Healthcare & diagnostics                                                                   4
# Housing                                                                                    4
# Advertisement & business revenue making                                                    3
# "Finance, banking & insurance"                                                             2
# Cultural representation, "Social media, sports, entertainment, & platforms"                2
# ...
